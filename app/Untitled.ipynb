# %%
import fitz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import fitz
#
# ModuleNotFoundError: No module named 'fitz'
